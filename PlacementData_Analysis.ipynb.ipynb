# %% [markdown]
# **Import necessary libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Load the dataset**

# %%
df=pd.read_csv("C:\\Users\\DELL\\Downloads\\Placement_Data_Full_Class.csv")

# %% [markdown]
# **Display first few row**

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %% [markdown]
# **Look at the last few rows**

# %%
df.tail()
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 210    211      M   80.6   Others   82.0  Others  Commerce      77.6
# 211    212      M   58.0   Others   60.0  Others   Science      72.0
# 212    213      M   67.0   Others   67.0  Others  Commerce      73.0
# 213    214      F   74.0   Others   66.0  Others  Commerce      58.0
# 214    215      M   62.0  Central   58.0  Others   Science      53.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN

# %% [markdown]
# **Check basic info**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %% [markdown]
# **Check for missing values**

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# **Check summary statistics**

# %%
df.describe(include='all')
# Out:
#              sl_no gender       ssc_p    ssc_b       hsc_p   hsc_b     hsc_s  \
# count   215.000000    215  215.000000      215  215.000000     215       215
# unique         NaN      2         NaN        2         NaN       2         3
# top            NaN      M         NaN  Central         NaN  Others  Commerce
# freq           NaN    139         NaN      116         NaN     131       113
# mean    108.000000    NaN   67.303395      NaN   66.333163     NaN       NaN
# std      62.209324    NaN   10.827205      NaN   10.897509     NaN       NaN
# min       1.000000    NaN   40.890000      NaN   37.000000     NaN       NaN
# 25%      54.500000    NaN   60.600000      NaN   60.900000     NaN       NaN
# 50%     108.000000    NaN   67.000000      NaN   65.000000     NaN       NaN
# 75%     161.500000    NaN   75.700000      NaN   73.000000     NaN       NaN
# max     215.000000    NaN   89.400000      NaN   97.700000     NaN       NaN
#
# ...

# %% [markdown]
# **Drop duplicates if any**

# %%
df.drop_duplicates()
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# **Drop rows with more than 5 missing values**

# %%
df.dropna(thresh=5)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# **View unique values of a column**

# %%
df['gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df['status'].unique()
# Out:
# array(['Placed', 'Not Placed'], dtype=object)

# %%
df['degree_t'].unique()
# Out:
# array(['Sci&Tech', 'Comm&Mgmt', 'Others'], dtype=object)

# %% [markdown]
# **Column names**

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %% [markdown]
# **Count of placed vs not placed**

# %%
df['status'].value_counts()
# Out:
# status
# Placed        148
# Not Placed     67
# Name: count, dtype: int64

# %% [markdown]
# **Gender-wise placement count**

# %%
df.groupby('gender')['status'].value_counts()
# Out:
# gender  status
# F       Placed         48
#         Not Placed     28
# M       Placed        100
#         Not Placed     39
# Name: count, dtype: int64

# %% [markdown]
# **Only numeric columns**

# %%
df.corr(numeric_only=True)
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.063764
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %% [markdown]
# **Sampling random rows**

# %%
df.sample(5)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 117    118      M  77.00   Others  75.00  Others   Science      73.0
# 81      82      M  81.70   Others  63.00  Others   Science      67.0
# 84      85      M  70.00  Central  63.00  Others   Science      70.0
# 85      86      F  83.84   Others  89.83  Others  Commerce      77.2
# 58      59      M  74.00  Central  62.00  Others   Science      68.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 117   Sci&Tech     No    80.00        Mkt&Fin  67.05  Placed  240000.0
# 81   Comm&Mgmt    Yes    86.00        Mkt&Fin  70.20  Placed  300000.0
# 84    Sci&Tech    Yes    55.00        Mkt&Fin  62.00  Placed  300000.0
# 85   Comm&Mgmt    Yes    78.74        Mkt&Fin  76.18  Placed  400000.0
# 58   Comm&Mgmt     No    74.00        Mkt&Fin  57.99  Placed  268000.0

# %% [markdown]
# **Histogram**

# %%
df['degree_p']
# Out:
# 0      58.00
# 1      77.48
# 2      64.00
# 3      52.00
# 4      73.30
#        ...
# 210    77.60
# 211    72.00
# 212    73.00
# 213    58.00
# 214    53.00
# Name: degree_p, Length: 215, dtype: float64

# %%
df['degree_p'].hist(bins=70)
# Out:
# <Axes: >

# %% [markdown]
# **Boxplot**

# %%
df.boxplot(column='degree_p', by='workex')
# Out:
# <Axes: title={'center': 'degree_p'}, xlabel='workex'>

# %% [markdown]
# **Scatter plot**

# %%
df.plot(kind='scatter', x='status', y='salary')
# Out:
# <Axes: xlabel='status', ylabel='salary'>
